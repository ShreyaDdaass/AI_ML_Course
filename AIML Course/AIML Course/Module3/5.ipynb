# %% [markdown]
# Practice Problems on File

# %% [markdown]
# Practice 1

# %%
with open ("new.txt","r")as file:
    string = file.read()
    print (string)
# Out:
# Hello,so you cannot see me ,you do not know .
# You buy me a chocolate.
# If you can not then get lost.
