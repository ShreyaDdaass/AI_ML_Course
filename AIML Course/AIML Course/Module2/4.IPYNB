# %% [markdown]
# Positional Arguments

# %% [markdown]
# Different types of arguments

# %%
def adder (a,b,c):
    print (f"{a}, {b}, {c}")

adder (2,4,3)
# Out:
# 2, 4, 3

# %%
def adder (*args):
    print (args)

adder (2,4,3,5)
# Out:
# (2, 4, 3, 5)

# %%
def adder (*args):
    for i in args:
        print (i)

adder (2,4,3,5)
# Out:
# 2
# 4
# 3
# 5
