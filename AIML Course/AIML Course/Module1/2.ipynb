# %% [markdown]
# Variable Types

# %%
a = 10
print(a)
print (type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 3.14
print(b)
print (type(b))
# Out:
# 3.14
# <class 'float'>

# %%
a = b
print(a)
print (type(a))
# Out:
# 3.14
# <class 'float'>

# %%
x = "Hello, World!"
print(x)
print (type(x))
# Out:
# Hello, World!
# <class 'str'>

# %%
data = input()
print(data)
print (type(data))
# Out:
# hello
# <class 'str'>

# %%
a = input()
a = int(a) # a = float(a) 
print(a)
print (type(a))
# Out:
# 10.23
# <class 'float'>

# %%
row_number = input()
# row_number = int(row_number)
numbers = row_number.split()
print (numbers)
print (type(numbers))
# print(row_number)
# print (type(row_number))
# Out:
# ['2312', '2121', '685']
# <class 'list'>

# %%
row_number = input()
numbers = row_number.split()
a = int(numbers[0])
print (a)
print (type(a))
b = int(numbers[2])
print (b)
print (type(b))
print ()
# Out:
# 10
# <class 'int'>
# 65
# <class 'int'>
